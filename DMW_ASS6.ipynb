# %%
Name - Almas Yunus Pathan
Batch Number - AB4
Roll Number - 14
UCS Number  - UCS19F1088
Assignment No -6(DMW)

# %% [markdown]
# # Visualization Techniques

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Boston.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(5)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'crim'}>,
#         <AxesSubplot:title={'center':'zn'}>,
#         <AxesSubplot:title={'center':'indus'}>],
#        [<AxesSubplot:title={'center':'chas'}>,
#         <AxesSubplot:title={'center':'nox'}>,
#         <AxesSubplot:title={'center':'rm'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'dis'}>,
#         <AxesSubplot:title={'center':'rad'}>,
#         <AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'ptratio'}>],
#        [<AxesSubplot:title={'center':'black'}>,
#         <AxesSubplot:title={'center':'lstat'}>,
#         <AxesSubplot:title={'center':'medv'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data.hist(figsize=(15,15),color="hotpink")
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'crim'}>,
#         <AxesSubplot:title={'center':'zn'}>,
#         <AxesSubplot:title={'center':'indus'}>],
#        [<AxesSubplot:title={'center':'chas'}>,
#         <AxesSubplot:title={'center':'nox'}>,
#         <AxesSubplot:title={'center':'rm'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'dis'}>,
#         <AxesSubplot:title={'center':'rad'}>,
#         <AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'ptratio'}>],
#        [<AxesSubplot:title={'center':'black'}>,
#         <AxesSubplot:title={'center':'lstat'}>,
#         <AxesSubplot:title={'center':'medv'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.barplot(df["zn"],df["indus"])
plt.title("barplot")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'barplot')

# %%
# Scatter plot with day against tip
plt.scatter(data['crim'], data['zn'], c=data['indus'],
            s=data['rm'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('crim')
plt.ylabel('zn')
 
plt.colorbar()
 
plt.show()

# %%
# Scatter plot zn against indus
plt.plot(data['zn'])
plt.plot(data['indus'])

# %%
# Bar chart with day against tip
plt.bar(data['zn'], data['rm'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('zn')
plt.ylabel('rm')
# Out:
# Text(0, 0.5, 'rm')

# %%
# draw lineplot
sns.lineplot(x="age", y="indus", data=data)
 
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
# Out:
# Text(0.5, 1.0, 'Title using Matplotlib Function')

# %%
labels=['zn','rm','indus']
sizes=[50,50,50]
plt.pie(sizes,labels=labels,explode=(0.1,0.1,0.1))
# Out:
# ([<matplotlib.patches.Wedge at 0x1dc9069e970>,
# ...
#  [Text(0.5999999675667398, 1.0392305032666773, 'zn'),
#   Text(-1.199999999999995, -1.1235210826980003e-07, 'rm'),
#   Text(0.6000001621662929, -1.0392303909145566, 'indus')])

# %%
sns.countplot(x='age', data=data)
plt.title("countplot for age")
# Out:
# Text(0.5, 1.0, 'countplot for age')
